# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json

# %%
csv = pd.read_csv("/content/3_Data.csv")
csv
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
ex = pd.read_excel("/content/1_Data.xlsx")
ex
# Out:
#       invoice_no customer_id         category  quantity invoice date    price  \
# 0        I138884     C241288         Clothing         5   05/08/2022  1500.40
# 1        I317333     C111565            Shoes         3   12/12/2021  1800.51
# 2        I127801     C266599         Clothing         1   09/11/2021   300.08
# 3        I173702     C988172            Shoes         5   05/16/2021  3000.85
# 4        I337046     C189076            Books         4   10/24/2021    60.60
# ...          ...         ...              ...       ...          ...      ...
# 99452    I219422     C441542         Souvenir         5   09/21/2022    58.65
# 99453    I325143     C569580  Food & Beverage         2   09/22/2021    10.46
# 99454    I824010     C103292  Food & Beverage         2   03/28/2021    10.46
# 99455    I702964     C800631       Technology         4   03/16/2021  4200.00
# 99456    I232867     C273973         Souvenir         3   10/15/2022    35.19
#
#                   shopping_mall
# ...

# %%
with open("/content/1_Data.json") as f:
  data = json.load(f)
data
# Out:
# [{'sepalLength': 5.1,
#   'sepalWidth': 3.5,
#   'petalLength': 1.4,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 4.9,
#   'sepalWidth': 3.0,
#   'petalLength': 1.4,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 4.7,
#   'sepalWidth': 3.2,
#   'petalLength': 1.3,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 4.6,
#   'sepalWidth': 3.1,
#   'petalLength': 1.5,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 5.0,
#   'sepalWidth': 3.6,
#   'petalLength': 1.4,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 5.4,
#   'sepalWidth': 3.9,
#   'petalLength': 1.7,
#   'petalWidth': 0.4,
#   'species': 'setosa'},
#  {'sepalLength': 4.6,
#   'sepalWidth': 3.4,
#   'petalLength': 1.4,
#   'petalWidth': 0.3,
#   'species': 'setosa'},
#  {'sepalLength': 5.0,
#   'sepalWidth': 3.4,
#   'petalLength': 1.5,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 4.4,
# ...

# %%
json = pd.DataFrame(data)
json
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
ex.shape
# Out:
# (99457, 7)

# %%
json.shape
# Out:
# (150, 5)

# %%
unified_data = pd.concat([ex, json], axis=1)
unified_data
# Out:
#       invoice_no customer_id         category  quantity invoice date    price  \
# 0        I138884     C241288         Clothing         5   05/08/2022  1500.40
# 1        I317333     C111565            Shoes         3   12/12/2021  1800.51
# 2        I127801     C266599         Clothing         1   09/11/2021   300.08
# 3        I173702     C988172            Shoes         5   05/16/2021  3000.85
# 4        I337046     C189076            Books         4   10/24/2021    60.60
# ...          ...         ...              ...       ...          ...      ...
# 99452    I219422     C441542         Souvenir         5   09/21/2022    58.65
# 99453    I325143     C569580  Food & Beverage         2   09/22/2021    10.46
# 99454    I824010     C103292  Food & Beverage         2   03/28/2021    10.46
# 99455    I702964     C800631       Technology         4   03/16/2021  4200.00
# 99456    I232867     C273973         Souvenir         3   10/15/2022    35.19
#
# ...

# %%
ex
# Out:
#       invoice_no customer_id         category  quantity invoice date    price  \
# 0        I138884     C241288         Clothing         5   05/08/2022  1500.40
# 1        I317333     C111565            Shoes         3   12/12/2021  1800.51
# 2        I127801     C266599         Clothing         1   09/11/2021   300.08
# 3        I173702     C988172            Shoes         5   05/16/2021  3000.85
# 4        I337046     C189076            Books         4   10/24/2021    60.60
# ...          ...         ...              ...       ...          ...      ...
# 99452    I219422     C441542         Souvenir         5   09/21/2022    58.65
# 99453    I325143     C569580  Food & Beverage         2   09/22/2021    10.46
# 99454    I824010     C103292  Food & Beverage         2   03/28/2021    10.46
# 99455    I702964     C800631       Technology         4   03/16/2021  4200.00
# 99456    I232867     C273973         Souvenir         3   10/15/2022    35.19
#
#                   shopping_mall
# ...

# %%
plt.figure(figsize=(100, 5))
ex["invoice date"].value_counts().plot(kind="bar")
plt.title("Invoice Date")
plt.xticks(rotation=90)
plt.show()
